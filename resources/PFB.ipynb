# %%
import os

avro_file_path = os.getenv("AVRO_FILE_PATH")

if avro_file_path is None:
    raise EnvironmentError("Environment variable 'AVRO_FILE_PATH' is not set.")

# %%
# !pip install pypfb
# !pip install pandas
# Out:
# Requirement already satisfied: pypfb in /opt/conda/lib/python3.10/site-packages (0.5.33)
# Requirement already satisfied: PyYAML>=6.0.1 in /opt/conda/lib/python3.10/site-packages (from pypfb) (6.0.2)
# Requirement already satisfied: aiohttp>=3.6.3 in /opt/conda/lib/python3.10/site-packages (from pypfb) (3.12.11)
# Requirement already satisfied: click>=8.1.7 in /opt/conda/lib/python3.10/site-packages (from pypfb) (8.2.1)
# Requirement already satisfied: dictionaryutils>=3.4.8 in /opt/conda/lib/python3.10/site-packages (from pypfb) (3.5.0)
# Requirement already satisfied: fastavro>=1.11.0 in /opt/conda/lib/python3.10/site-packages (from pypfb) (1.11.1)
# Requirement already satisfied: gen3>=4.11.3 in /opt/conda/lib/python3.10/site-packages (from pypfb) (4.27.2)
# Requirement already satisfied: gen3dictionary>=2.0.3 in /opt/conda/lib/python3.10/site-packages (from pypfb) (2.0.4)
# Requirement already satisfied: python-json-logger>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from pypfb) (2.0.7)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp>=3.6.3->pypfb) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/conda/lib/python3.10/site-packages (from aiohttp>=3.6.3->pypfb) (1.3.2)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp>=3.6.3->pypfb) (5.0.1)
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp>=3.6.3->pypfb) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from aiohttp>=3.6.3->pypfb) (1.6.2)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/conda/lib/python3.10/site-packages (from aiohttp>=3.6.3->pypfb) (6.4.4)
# Requirement already satisfied: propcache>=0.2.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp>=3.6.3->pypfb) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp>=3.6.3->pypfb) (1.20.0)
# Requirement already satisfied: cdislogging in /opt/conda/lib/python3.10/site-packages (from dictionaryutils>=3.4.8->pypfb) (1.1.1)
# Requirement already satisfied: jsonschema<=4.23.0 in /opt/conda/lib/python3.10/site-packages (from dictionaryutils>=3.4.8->pypfb) (4.17.3)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from dictionaryutils>=3.4.8->pypfb) (2.31.0)
# Requirement already satisfied: aiofiles<0.9.0,>=0.8.0 in /opt/conda/lib/python3.10/site-packages (from gen3>=4.11.3->pypfb) (0.8.0)
# Requirement already satisfied: backoff in /opt/conda/lib/python3.10/site-packages (from gen3>=4.11.3->pypfb) (1.11.1)
# Requirement already satisfied: dataclasses-json<=0.5.9 in /opt/conda/lib/python3.10/site-packages (from gen3>=4.11.3->pypfb) (0.5.9)
# Requirement already satisfied: drsclient>=0.3.0 in /opt/conda/lib/python3.10/site-packages (from gen3>=4.11.3->pypfb) (0.3.0)
# Requirement already satisfied: gen3users in /opt/conda/lib/python3.10/site-packages (from gen3>=4.11.3->pypfb) (1.1.1)
# Requirement already satisfied: httpx in /opt/conda/lib/python3.10/site-packages (from gen3>=4.11.3->pypfb) (0.27.2)
# Requirement already satisfied: humanfriendly in /opt/conda/lib/python3.10/site-packages (from gen3>=4.11.3->pypfb) (10.0)
# Requirement already satisfied: indexclient<3.0.0,>=2.3.0 in /opt/conda/lib/python3.10/site-packages (from gen3>=4.11.3->pypfb) (2.3.1)
# Requirement already satisfied: pandas>=1.4.2 in /opt/conda/lib/python3.10/site-packages (from gen3>=4.11.3->pypfb) (2.3.0)
# Requirement already satisfied: python-dateutil in /opt/conda/lib/python3.10/site-packages (from gen3>=4.11.3->pypfb) (2.8.2)
# Requirement already satisfied: tqdm<5.0.0,>=4.61.2 in /opt/conda/lib/python3.10/site-packages (from gen3>=4.11.3->pypfb) (4.65.0)
# Requirement already satisfied: urllib3>2.0.0 in /opt/conda/lib/python3.10/site-packages (from gen3>=4.11.3->pypfb) (2.0.2)
# Requirement already satisfied: xmltodict<0.14.0,>=0.13.0 in /opt/conda/lib/python3.10/site-packages (from gen3>=4.11.3->pypfb) (0.13.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.3.0 in /opt/conda/lib/python3.10/site-packages (from dataclasses-json<=0.5.9->gen3>=4.11.3->pypfb) (3.26.1)
# Requirement already satisfied: marshmallow-enum<2.0.0,>=1.5.1 in /opt/conda/lib/python3.10/site-packages (from dataclasses-json<=0.5.9->gen3>=4.11.3->pypfb) (1.5.1)
# Requirement already satisfied: typing-inspect>=0.4.0 in /opt/conda/lib/python3.10/site-packages (from dataclasses-json<=0.5.9->gen3>=4.11.3->pypfb) (0.9.0)
# Requirement already satisfied: asyncio<4.0.0,>=3.4.3 in /opt/conda/lib/python3.10/site-packages (from drsclient>=0.3.0->gen3>=4.11.3->pypfb) (3.4.3)
# Requirement already satisfied: anyio in /opt/conda/lib/python3.10/site-packages (from httpx->gen3>=4.11.3->pypfb) (3.6.2)
# Requirement already satisfied: certifi in /opt/conda/lib/python3.10/site-packages (from httpx->gen3>=4.11.3->pypfb) (2023.5.7)
# Requirement already satisfied: httpcore==1.* in /opt/conda/lib/python3.10/site-packages (from httpx->gen3>=4.11.3->pypfb) (1.0.9)
# Requirement already satisfied: idna in /opt/conda/lib/python3.10/site-packages (from httpx->gen3>=4.11.3->pypfb) (3.4)
# Requirement already satisfied: sniffio in /opt/conda/lib/python3.10/site-packages (from httpx->gen3>=4.11.3->pypfb) (1.3.0)
# Requirement already satisfied: h11>=0.16 in /opt/conda/lib/python3.10/site-packages (from httpcore==1.*->httpx->gen3>=4.11.3->pypfb) (0.16.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /opt/conda/lib/python3.10/site-packages (from jsonschema<=4.23.0->dictionaryutils>=3.4.8->pypfb) (0.19.3)
# Requirement already satisfied: typing-extensions>=4.1.0 in /opt/conda/lib/python3.10/site-packages (from multidict<7.0,>=4.5->aiohttp>=3.6.3->pypfb) (4.6.2)
# Requirement already satisfied: numpy>=1.22.4 in /opt/conda/lib/python3.10/site-packages (from pandas>=1.4.2->gen3>=4.11.3->pypfb) (2.2.6)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas>=1.4.2->gen3>=4.11.3->pypfb) (2023.3)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.10/site-packages (from pandas>=1.4.2->gen3>=4.11.3->pypfb) (2025.2)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil->gen3>=4.11.3->pypfb) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->dictionaryutils>=3.4.8->pypfb) (3.1.0)
# Requirement already satisfied: packaging>=17.0 in /opt/conda/lib/python3.10/site-packages (from marshmallow<4.0.0,>=3.3.0->dataclasses-json<=0.5.9->gen3>=4.11.3->pypfb) (23.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /opt/conda/lib/python3.10/site-packages (from typing-inspect>=0.4.0->dataclasses-json<=0.5.9->gen3>=4.11.3->pypfb) (1.1.0)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.10/site-packages (2.3.0)
# Requirement already satisfied: numpy>=1.22.4 in /opt/conda/lib/python3.10/site-packages (from pandas) (2.2.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.10/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas) (2023.3)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.10/site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.3.0 in /opt/conda/lib/python3.10/site-packages (from dataclasses-json<=0.5.9->gen3>=4.11.3->pypfb) (3.26.1)
# Requirement already satisfied: marshmallow-enum<2.0.0,>=1.5.1 in /opt/conda/lib/python3.10/site-packages (from dataclasses-json<=0.5.9->gen3>=4.11.3->pypfb) (1.5.1)
# Requirement already satisfied: typing-inspect>=0.4.0 in /opt/conda/lib/python3.10/site-packages (from dataclasses-json<=0.5.9->gen3>=4.11.3->pypfb) (0.9.0)
# Requirement already satisfied: asyncio<4.0.0,>=3.4.3 in /opt/conda/lib/python3.10/site-packages (from drsclient>=0.3.0->gen3>=4.11.3->pypfb) (3.4.3)
# Requirement already satisfied: anyio in /opt/conda/lib/python3.10/site-packages (from httpx->gen3>=4.11.3->pypfb) (3.6.2)
# Requirement already satisfied: certifi in /opt/conda/lib/python3.10/site-packages (from httpx->gen3>=4.11.3->pypfb) (2023.5.7)
# Requirement already satisfied: httpcore==1.* in /opt/conda/lib/python3.10/site-packages (from httpx->gen3>=4.11.3->pypfb) (1.0.9)
# Requirement already satisfied: idna in /opt/conda/lib/python3.10/site-packages (from httpx->gen3>=4.11.3->pypfb) (3.4)
# Requirement already satisfied: sniffio in /opt/conda/lib/python3.10/site-packages (from httpx->gen3>=4.11.3->pypfb) (1.3.0)
# Requirement already satisfied: h11>=0.16 in /opt/conda/lib/python3.10/site-packages (from httpcore==1.*->httpx->gen3>=4.11.3->pypfb) (0.16.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /opt/conda/lib/python3.10/site-packages (from jsonschema<=4.23.0->dictionaryutils>=3.4.8->pypfb) (0.19.3)
# Requirement already satisfied: typing-extensions>=4.1.0 in /opt/conda/lib/python3.10/site-packages (from multidict<7.0,>=4.5->aiohttp>=3.6.3->pypfb) (4.6.2)
# Requirement already satisfied: numpy>=1.22.4 in /opt/conda/lib/python3.10/site-packages (from pandas>=1.4.2->gen3>=4.11.3->pypfb) (2.2.6)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas>=1.4.2->gen3>=4.11.3->pypfb) (2023.3)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.10/site-packages (from pandas>=1.4.2->gen3>=4.11.3->pypfb) (2025.2)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil->gen3>=4.11.3->pypfb) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->dictionaryutils>=3.4.8->pypfb) (3.1.0)
# Requirement already satisfied: packaging>=17.0 in /opt/conda/lib/python3.10/site-packages (from marshmallow<4.0.0,>=3.3.0->dataclasses-json<=0.5.9->gen3>=4.11.3->pypfb) (23.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /opt/conda/lib/python3.10/site-packages (from typing-inspect>=0.4.0->dataclasses-json<=0.5.9->gen3>=4.11.3->pypfb) (1.1.0)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.10/site-packages (2.3.0)
# Requirement already satisfied: numpy>=1.22.4 in /opt/conda/lib/python3.10/site-packages (from pandas) (2.2.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.10/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas) (2023.3)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.10/site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
from pfb.reader import PFBReader
import pandas as pd


try:
    with PFBReader(avro_file_path) as reader:

        # print("PFB Schema:")
        # print(reader.schema)

        # print("PFB Metadata:")
        # print(reader.metadata)

        records = list(reader)

        df = pd.DataFrame(records)


except Exception as e:
    print(f"Error: {e}")

# %%
df.head()
# Out:
#                                      id     name  \
# 0  02d65a1a-7f0c-52a1-9880-dc2e4e709ebb  program
# 1  dd3e0b03-674b-56f0-866c-732c7c710faa  project
# 2  0113c5dd-bd93-4d76-b862-2af5d29d7d35   person
# 3  01368d1f-8a82-4870-a819-2d551f29c6be   person
# 4  01a2d3e3-9776-4598-a0de-1f31b7db2c89   person
#
#                                               object  \
# 0  {'name': 'pcdc', 'dbgap_accession_number': 'pc...
# 1  {'name': 'nasi_setulous', 'description': 'nonp...
# 2  {'submitter_id': 'person_Alamannic_Amuchco', '...
# 3  {'submitter_id': 'person_quivering_palliditars...
# 4  {'submitter_id': 'person_pionnotes_elater', 's...
#
#                                            relations
# 0                                                 []
# 1  [{'dst_id': '02d65a1a-7f0c-52a1-9880-dc2e4e709...
# 2  [{'dst_id': 'dd3e0b03-674b-56f0-866c-732c7c710...
# 3  [{'dst_id': 'dd3e0b03-674b-56f0-866c-732c7c710...
# 4  [{'dst_id': 'dd3e0b03-674b-56f0-866c-732c7c710...
